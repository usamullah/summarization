# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# !pip install transformers
# !pip install torch
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
import torch
import json
from transformers import T5Tokenizer, T5ForConditionalGeneration, T5Config

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# model = T5ForConditionalGeneration.from_pretrained('t5-small')
# tokenizer = T5Tokenizer.from_pretrained('t5-small')
# device = torch.device('cpu')

# %%
import os

# Define the directory path where you want to save the model
output_dir = "/content/drive/My Drive/summary model"

# %%
text ="""

In the heart of the bustling metropolis, where skyscrapers kissed
the clouds and the streets thrummed with the energy of a million souls,
 there existed a labyrinth of alleyways concealed from the gaze of the casual passerby.
 Here, amidst the shadows and the echoes of distant footsteps, lay a hidden world teeming
 with life. It was a place where the forgotten found refuge, where artists adorned the
  walls with vibrant murals, and where whispers of ancient tales lingered in the air like the scent
   of rain before a storm. Within this clandestine realm, a tapestry of humanity unfolded – each thread woven with
    stories of hope and despair, of triumphs and tragedies that intertwined to form the fabric of existence. Amidst the chaos of urban life,
     there existed a harmony in the symphony of voices that echoed through the narrow streets, a rhythm that pulsed with the heartbeat of the city itself
     . And in the quiet moments between the cacophony of noise, one could glimpse the beauty that lay hidden within the cracks of the concrete jungle,
      a reminder that even in the darkest of places, there existed the possibility of light.
"""

# %%
preprocess_text = text.strip().replace("\n","")
t5_prepared_Text = "summarize: "+preprocess_text
print ("original text preprocessed: \n", preprocess_text)
# Out:
# original text preprocessed:
# ...

# %%
tokenized_text = tokenizer.encode(t5_prepared_Text, return_tensors="pt").to(device)

# %%
# summmarize
summary_ids = model.generate(tokenized_text,
                                    num_beams=4,
                                    no_repeat_ngram_size=2,
                                    min_length=30,
                                    max_length=100,
                                    early_stopping=True)

# %%
output = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

print ("\n\nSummarized text: \n",output)
# Out:
# Summarized text:
#  a tapestry of humanity unfolded within this clandestine realm, each thread woven with stories of hope and despair, of triumphs and tragedies that intertwine to form the fabric of existence. in the quiet moments between the cacophony of noise, one could glimpse the beauty that lay hidden within the cracks of the concrete jungle.

# %%
model.save_pretrained(output_dir)
# tokenizer.save_pretrained(output_dir)
# save_directory = "/content/drive/My Drive/summary model"

# Save model weights
torch.save(model.state_dict(), output_dir + "/pytorch_model.bin")

# Save tokenizer
tokenizer.save_pretrained(output_dir)

# Optionally, save model configuration
model.config.save_pretrained(output_dir)

# %%
model = T5ForConditionalGeneration.from_pretrained(output_dir)
tokenizer = T5Tokenizer.from_pretrained(output_dir)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
